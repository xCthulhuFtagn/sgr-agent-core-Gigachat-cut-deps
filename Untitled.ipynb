# %%
# !pip install build
# Out:
# Looking in indexes: https://token:****@sberosc.sigma.sbrf.ru/repo/pypi/simple, https://token:****@sberosc.sigma.sbrf.ru/repo/nvidia_pypi
# ...
# WARNING: 401 Error, Credentials not correct for https://sberosc.sigma.sbrf.ru/repo/pypi/simple/pip/
# WARNING: 401 Error, Credentials not correct for https://sberosc.sigma.sbrf.ru/repo/nvidia_pypi/pip/

# %%
# import os
# import argparse

# def find_and_replace(directory, old_string, new_string, dry_run=False):
#     """Проходит по всем файлам в директории и заменяет подстроку."""
#     count = 0
#     for root, _, filenames in os.walk(directory):
#         for filename in filenames:
#             file_path = os.path.join(root, filename)
#             try:
#                 # Читаем содержимое файла
#                 with open(file_path, 'r', encoding='utf-8') as file:
#                     content = file.read()

#                 # Проверяем наличие старой подстроки
#                 if old_string in content:
#                     print(f"Найдено совпадение в файле: {file_path}")
#                     count += 1

#                     # Замещаем подстроку, если не dry-run
#                     if not dry_run:
#                         updated_content = content.replace(old_string, new_string)
#                         with open(file_path, 'w', encoding='utf-8') as file:
#                             file.write(updated_content)
#                         print(f"Успешно заменено в файле: {file_path}")

#             except Exception as e:
#                 print(f"Пропущен файл {file_path}: {str(e)}")

#     print(f"\n🎉 Всего обработано {count} файл{'ов' if count != 1 else ''}!")

# def main():
#     find_and_replace(".", "sgr_deep_research_core", "sgr_deep_research.core", False)

# if __name__ == '__main__':
#     main()

# %%
# !python -m build
# Out:
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools>=64.0
#   - wheel
# * Getting build dependencies for sdist...
# running egg_info
# writing sgr_deep_research.egg-info/PKG-INFO
# writing dependency_links to sgr_deep_research.egg-info/dependency_links.txt
# writing entry points to sgr_deep_research.egg-info/entry_points.txt
# writing requirements to sgr_deep_research.egg-info/requires.txt
# writing top-level names to sgr_deep_research.egg-info/top_level.txt
# reading manifest file 'sgr_deep_research.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...
# adding license file 'LICENSE'
# writing manifest file 'sgr_deep_research.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing sgr_deep_research.egg-info/PKG-INFO
# writing dependency_links to sgr_deep_research.egg-info/dependency_links.txt
# writing entry points to sgr_deep_research.egg-info/entry_points.txt
# ...

# %%
import sgr_deep_research
